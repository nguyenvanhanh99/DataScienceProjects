# %%
import urllib.request as url
from bs4 import BeautifulSoup
import requests
import shutil

# %%
#https://celebmafia.com/selena-gomez/page/5/
wiki = "http://celebmafia.com/selena-gomez/"

# %%
r = urllib.request.Request(wiki, headers= {'User-Agent' : 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36'})
html = urllib.request.urlopen(r)
#page = url.urlopen(wiki)

# %%
soup = BeautifulSoup(html)
# Out:
# C:\Users\conne\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\conne\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US" prefix="og: http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/favicon-196x196.png" rel="icon" sizes="196x196" type="image/png"/>
# ...

# %%
k =soup.find_all('a')

# %%
print(k[3])
# Out:
# <a href="https://celebmafia.com/category/celebrity-photos/" itemprop="url" title="Celebrity Photos"><span itemprop="name">Celebrity Photos</span></a>

# %%
nextlink = soup.findAll("a", {"class" : "more-link"})

# %%
allPageLinks =[]
for nextlink1 in soup.findAll("a", {"class" : "more-link"}):
    a = nextlink1.get('href')
    allPageLinks.append(a)

# %%
allPageLinks
# Out:
# ['https://celebmafia.com/selena-gomez-in-jeans-and-ac-dc-t-shirt-1528437/',
#  'https://celebmafia.com/selena-gomez-and-caleb-stevens-night-out-at-the-forum-in-inglewood-07-24-2018-1526082/',
#  'https://celebmafia.com/selena-gomez-wallpapers-3-1523884/',
#  'https://celebmafia.com/selena-gomez-street-style-out-for-breakfast-in-studio-city-07-25-2018-1523772/',
#  'https://celebmafia.com/selena-gomez-out-in-malibu-07-24-2018-1520546/',
#  'https://celebmafia.com/selena-gomez-in-upstate-new-york-07-12-2018-1500314/',
#  'https://celebmafia.com/selena-gomez-on-the-set-of-her-new-zombie-movie-kill-the-head-in-fleischmanns-ny-07-12-2018-1499018/',
#  'https://celebmafia.com/selena-gomez-on-a-yacht-in-new-york-1495092/',
#  'https://celebmafia.com/selena-gomez-goes-on-a-yacht-in-new-york-07-08-2018-1494249/',
#  'https://celebmafia.com/selena-gomez-pumas-autumn-winter-2018-collection-1494019/']

# %%
imgURL = "https://celebmafia.com/selena-gomez-in-jeans-and-ac-dc-t-shirt-1528437/"
r1 = urllib.request.Request(imgURL, headers= {'User-Agent' : 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36'})
html1 = urllib.request.urlopen(r1)

# %%
soup = BeautifulSoup(html1)
# Out:
# C:\Users\conne\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\conne\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
allimageLinks =[]
for nextlink1 in soup.findAll("a"):
    a = nextlink1.get('href')
    allimageLinks.append(a)
lo = [s for s in allimageLinks if '.jpg' in s]

# %%
lo
# Out:
# ['https://celebmafia.com/wp-content/uploads/2018/07/selena-gomez-in-jeans-and-ac-dc-t-shirt-15.jpg',
#  'https://celebmafia.com/wp-content/uploads/2018/07/selena-gomez-in-jeans-and-ac-dc-t-shirt-0.jpg',
#  'https://celebmafia.com/wp-content/uploads/2018/07/selena-gomez-in-jeans-and-ac-dc-t-shirt-1.jpg',
#  'https://celebmafia.com/wp-content/uploads/2018/07/selena-gomez-in-jeans-and-ac-dc-t-shirt-2.jpg',
#  'https://celebmafia.com/wp-content/uploads/2018/07/selena-gomez-in-jeans-and-ac-dc-t-shirt-3.jpg',
#  'https://celebmafia.com/wp-content/uploads/2018/07/selena-gomez-in-jeans-and-ac-dc-t-shirt-4.jpg',
#  'https://celebmafia.com/wp-content/uploads/2018/07/selena-gomez-in-jeans-and-ac-dc-t-shirt-5.jpg',
#  'https://celebmafia.com/wp-content/uploads/2018/07/selena-gomez-in-jeans-and-ac-dc-t-shirt-6.jpg',
#  'https://celebmafia.com/wp-content/uploads/2018/07/selena-gomez-in-jeans-and-ac-dc-t-shirt-7.jpg',
# ...

# %%
#url.urlretrieve("https://celebmafia.com/wp-content/uploads/2018/07/selena-gomez-in-jeans-and-ac-dc-t-shirt-15.jpg", "00000001.jpg",{'User-Agent' : 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36'})
import requests
r = requests.get('https://celebmafia.com/wp-content/uploads/2018/07/selena-gomez-in-jeans-and-ac-dc-t-shirt-15.jpg',
                 stream=True, headers={'User-agent': 'Mozilla/5.0'})

# %%
r.raw

# %%
import requests
import shutil


for image in lo:
    r = requests.get(image, stream=True)
    if r.status_code == 200:
        print('img' + str(lo.index(image)) +'.jpg')
        with open('img' + str(lo.index(image)) +'.jpg', 'wb') as f:
            r.raw.decode_content = True
            shutil.copyfileobj(r.raw, f)
# Out:
# img0.jpg
# img1.jpg
# img2.jpg
# img3.jpg
# img4.jpg
# img5.jpg
# img6.jpg
# img7.jpg
# img8.jpg
# img9.jpg
# img10.jpg
# img11.jpg
# img12.jpg
# img13.jpg
# img14.jpg
# img15.jpg

# %%
import urllib.request as url
from bs4 import BeautifulSoup
import requests
import shutil
import os, sys

def downloadAllImages(celeb,fromPage,numberOfPages):
    urli = 'http://celebmafia.com/' +celeb+'/'
    for i in range(fromPage,fromPage+numberOfPages+1):
        wiki = urli+"page/"+str(i)+'/'
        print(wiki)
        r = url.Request(wiki, headers= {'User-Agent' : 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36'})
        html = url.urlopen(r)
        soup = BeautifulSoup(html)
        allPageLinks =[]
        for nextlink1 in soup.findAll("a", {"class" : "more-link"}):
            a = nextlink1.get('href')
            allPageLinks.append(a)
        print(os.getcwd())
        os.mkdir(celeb)
        os.chdir(celeb)
        for pagelink in allPageLinks:
            imgURL = pagelink
            r1 = url.Request(imgURL, headers= {'User-Agent' : 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36'})
            html1 = url.urlopen(r1)
            soup = BeautifulSoup(html1)
            allimageLinks =[]
            for nextlink1 in soup.findAll("a"):
                a = nextlink1.get('href')
                allimageLinks.append(a)
            lo = [s for s in allimageLinks if '.jpg' in s]
            
            
            
            for image in lo:
                r = requests.get(image, stream=True)
                if r.status_code == 200:
                    print('img' + str(allPageLinks.index(pagelink))+ str(lo.index(image)) +'.jpg')
                    with open('img' +  str(allPageLinks.index(pagelink))+ str(lo.index(image)) +'.jpg', 'wb') as f:
                        r.raw.decode_content = True
                        shutil.copyfileobj(r.raw, f)

# %%
#downloadAllImages('ariel-winter',1,5)
#downloadAllImages('jennifer-lawrence',1,5)
downloadAllImages('kaley-cuoco',1,5)
# Out:
# http://celebmafia.com/kaley-cuoco/page/1/
# C:\Users\conne\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\conne\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# C:\Users\conne\Documents\Data Science\WebScraping
# img00.jpg
# img01.jpg
# img02.jpg
# img03.jpg
# img04.jpg
# img05.jpg
# img06.jpg
# img07.jpg
# img08.jpg
# img09.jpg
# img10.jpg
# img11.jpg
# img12.jpg
# img13.jpg
# img14.jpg
# img15.jpg
# img16.jpg
# img20.jpg
# img21.jpg
# img30.jpg
# img31.jpg
# img32.jpg
# ...

# %%
import os, sys
celeb = 'ariel-winter'

print(os.getcwd())
fileobj1 =os.mkdir(celeb)
fileobj2 = os.chdir(celeb)
fileobj1.close()
fileobj2.close()
# Out:
# C:\Users\conne\Documents\Data Science\WebScraping\ariel-winter\ariel-winter
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-61de515a6f7c> in <module>()
#       5 fileobj1 =os.mkdir(celeb)
#       6 fileobj2 = os.chdir(celeb)
# ----> 7 fileobj1.close()
#       8 fileobj2.close()
#
# AttributeError: 'NoneType' object has no attribute 'close'
