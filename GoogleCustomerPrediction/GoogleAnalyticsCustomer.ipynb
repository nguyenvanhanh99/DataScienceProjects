# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
dataset = pd.read_csv('train.csv')
# dataset.describe()
# dataset.shape
# dataset.head(5)
# Out:
# C:\Users\conne\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dataset.head(5)
# Out:
#   channelGrouping      date  \
# 0  Organic Search  20160902
# 1  Organic Search  20160902
# 2  Organic Search  20160902
# 3  Organic Search  20160902
# 4  Organic Search  20160902
#
#                                               device        fullVisitorId  \
# 0  {"browser": "Chrome", "browserVersion": "not a...  1131660440785968503
# 1  {"browser": "Firefox", "browserVersion": "not ...   377306020877927890
# 2  {"browser": "Chrome", "browserVersion": "not a...  3895546263509774583
# 3  {"browser": "UC Browser", "browserVersion": "n...  4763447161404445595
# 4  {"browser": "Chrome", "browserVersion": "not a...    27294437909732085
#
#                                           geoNetwork  \
# 0  {"continent": "Asia", "subContinent": "Western...
# 1  {"continent": "Oceania", "subContinent": "Aust...
# 2  {"continent": "Europe", "subContinent": "South...
# 3  {"continent": "Asia", "subContinent": "Southea...
# 4  {"continent": "Europe", "subContinent": "North...
#
# ...

# %%
dataset.shape
# Out:
# (903653, 12)

# %%
dataset['device'][1]
# Out:
# '{"browser": "Firefox", "browserVersion": "not available in demo dataset", "browserSize": "not available in demo dataset", "operatingSystem": "Macintosh", "operatingSystemVersion": "not available in demo dataset", "isMobile": false, "mobileDeviceBranding": "not available in demo dataset", "mobileDeviceModel": "not available in demo dataset", "mobileInputSelector": "not available in demo dataset", "mobileDeviceInfo": "not available in demo dataset", "mobileDeviceMarketingName": "not available in demo dataset", "flashVersion": "not available in demo dataset", "language": "not available in demo dataset", "screenColors": "not available in demo dataset", "screenResolution": "not available in demo dataset", "deviceCategory": "desktop"}'

# %% [markdown]
# Identify the keys that comes as part of the dictionary set in some of the attributes like device , totals, geoNetwork and traffic source

# %%
import json
d_device =json.loads(dataset['device'][1])
d_totals =json.loads(dataset['totals'][1])
d_geoNetwork =json.loads(dataset['geoNetwork'][1])
d_trafficSource =json.loads(dataset['trafficSource'][1])

# %%
print(d_device.keys())
print(d_totals.keys())
print(d_geoNetwork.keys())
print(d_trafficSource.keys())

attributesInd_device =list(d_device.keys())
attributesInd_totals =list(d_totals.keys())
attributesInd_geoNetwork =list(d_geoNetwork.keys())
attributesInd_trafficSource =list(d_trafficSource.keys())
# Out:
# dict_keys(['browser', 'browserVersion', 'browserSize', 'operatingSystem', 'operatingSystemVersion', 'isMobile', 'mobileDeviceBranding', 'mobileDeviceModel', 'mobileInputSelector', 'mobileDeviceInfo', 'mobileDeviceMarketingName', 'flashVersion', 'language', 'screenColors', 'screenResolution', 'deviceCategory'])
# dict_keys(['visits', 'hits', 'pageviews', 'bounces', 'newVisits'])
# dict_keys(['continent', 'subContinent', 'country', 'region', 'metro', 'city', 'cityId', 'networkDomain', 'latitude', 'longitude', 'networkLocation'])
# dict_keys(['campaign', 'source', 'medium', 'keyword', 'adwordsClickInfo'])

# %%
print(dataset['geoNetwork'][1])
print(dataset['trafficSource'][1])
# Out:
# {"continent": "Oceania", "subContinent": "Australasia", "country": "Australia", "region": "not available in demo dataset", "metro": "not available in demo dataset", "city": "not available in demo dataset", "cityId": "not available in demo dataset", "networkDomain": "dodo.net.au", "latitude": "not available in demo dataset", "longitude": "not available in demo dataset", "networkLocation": "not available in demo dataset"}
# {"campaign": "(not set)", "source": "google", "medium": "organic", "keyword": "(not provided)", "adwordsClickInfo": {"criteriaParameters": "not available in demo dataset"}}

# %% [markdown]
# Create a subset of data to check the piece of code that can be used to break the device field into multiple columns

# %%
df = dataset.iloc[1:1000,]

# %%
df.describe()
# Out:
#              date       visitId  visitNumber  visitStartTime
# count       999.0  9.990000e+02   999.000000    9.990000e+02
# mean   20160902.0  1.472841e+09     2.036036    1.472841e+09
# std           0.0  2.241278e+04     6.518565    2.241280e+04
# min    20160902.0  1.472800e+09     1.000000    1.472800e+09
# 25%    20160902.0  1.472824e+09     1.000000    1.472824e+09
# 50%    20160902.0  1.472840e+09     1.000000    1.472840e+09
# 75%    20160902.0  1.472858e+09     1.000000    1.472858e+09
# max    20160902.0  1.472886e+09   136.000000    1.472886e+09

# %%
len(attributesInd_device) + len(attributesInd_totals) + len(attributesInd_geoNetwork) + len(attributesInd_trafficSource)+dataset.shape[1]
# Out:
# 49

# %%
for attr in attributesInd_device:
    df[attr] = df['device'].apply(lambda x:(json.loads(x)).get(attr))
# Out:
# C:\Users\conne\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
for attr in attributesInd_totals:
    df[attr] = df['totals'].apply(lambda x:(json.loads(x)).get(attr))
# Out:
# C:\Users\conne\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
for attr in attributesInd_geoNetwork:
    df[attr] = df['geoNetwork'].apply(lambda x:(json.loads(x)).get(attr))
# Out:
# C:\Users\conne\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
for attr in attributesInd_trafficSource:
    df[attr] = df['trafficSource'].apply(lambda x:(json.loads(x)).get(attr))
# Out:
# C:\Users\conne\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df = df.drop('trafficSource', 1)
df = df.drop('geoNetwork', 1)
df = df.drop('totals', 1)
df = df.drop('device', 1)

# %%
df.columns
# Out:
# Index(['channelGrouping', 'date', 'fullVisitorId', 'sessionId',
#        'socialEngagementType', 'visitId', 'visitNumber', 'visitStartTime',
#        'browser', 'browserVersion', 'browserSize', 'operatingSystem',
#        'operatingSystemVersion', 'isMobile', 'mobileDeviceBranding',
#        'mobileDeviceModel', 'mobileInputSelector', 'mobileDeviceInfo',
#        'mobileDeviceMarketingName', 'flashVersion', 'language', 'screenColors',
#        'screenResolution', 'deviceCategory', 'visits', 'hits', 'pageviews',
#        'bounces', 'newVisits', 'continent', 'subContinent', 'country',
#        'region', 'metro', 'city', 'cityId', 'networkDomain', 'latitude',
#        'longitude', 'networkLocation', 'campaign', 'source', 'medium',
#        'keyword', 'adwordsClickInfo'],
#       dtype='object')

# %%
df.iloc[:,41:50]
# Out:
#                   source    medium           keyword  \
# 1                 google   organic    (not provided)
# 2                 google   organic    (not provided)
# 3                 google   organic   google + online
# 4                 google   organic    (not provided)
# 5                 google   organic    (not provided)
# 6                 google   organic    (not provided)
# 7                 google   organic    (not provided)
# 8                 google   organic    (not provided)
# 9                 google   organic    (not provided)
# 10                google   organic    (not provided)
# 11                google   organic    (not provided)
# 12                google   organic    (not provided)
# 13                google   organic    (not provided)
# 14                google   organic    (not provided)
# 15                 baidu   organic              None
# 16                google   organic    (not provided)
# 17                google   organic    (not provided)
# ...

# %%
df['adwordsClickInfo'][994]
# Out:
# {'page': '1',
#  'slot': 'Top',
#  'criteriaParameters': 'not available in demo dataset',
#  'gclId': 'Cj0KEQjwxqS-BRDRgPLp0q2t0IUBEiQAgfMXRHDrNcvrvrYYDhLvtL3_RKxH3WUh7NeqnjidFn0oncUaAuuy8P8HAQ',
#  'adNetworkType': 'Google Search',
#  'isVideoAd': False}

# %% [markdown]
# Using the same processing on the main dataset

# %%
for attr in attributesInd_device:
    print('device:'+ attr)
    dataset[attr] = dataset['device'].apply(lambda x:(json.loads(x)).get(attr))
for attr in attributesInd_totals:
    print('totals:'+ attr)
    dataset[attr] = dataset['totals'].apply(lambda x:(json.loads(x)).get(attr))
for attr in attributesInd_geoNetwork:
    print('geoNetwork:'+ attr)
    dataset[attr] = dataset['geoNetwork'].apply(lambda x:(json.loads(x)).get(attr))
for attr in attributesInd_trafficSource:
    print('trafficSource:'+ attr)
    dataset[attr] = dataset['trafficSource'].apply(lambda x:(json.loads(x)).get(attr))
# Out:
# device:browser
# device:browserVersion
# device:browserSize
# device:operatingSystem
# device:operatingSystemVersion
# device:isMobile
# device:mobileDeviceBranding
# device:mobileDeviceModel
# device:mobileInputSelector
# device:mobileDeviceInfo
# device:mobileDeviceMarketingName
# device:flashVersion
# device:language
# device:screenColors
# device:screenResolution
# device:deviceCategory
# totals:visits
# totals:hits
# totals:pageviews
# totals:bounces
# totals:newVisits
# geoNetwork:continent
# geoNetwork:subContinent
# geoNetwork:country
# geoNetwork:region
# geoNetwork:metro
# geoNetwork:city
# geoNetwork:cityId
# geoNetwork:networkDomain
# geoNetwork:latitude
# geoNetwork:longitude
# geoNetwork:networkLocation
# trafficSource:campaign
# trafficSource:source
# trafficSource:medium
# trafficSource:keyword
# trafficSource:adwordsClickInfo

# %%
dataset = dataset.drop('trafficSource', 1)
dataset = dataset.drop('geoNetwork', 1)
dataset = dataset.drop('totals', 1)
dataset = dataset.drop('device', 1)

# %%
dataset.head(10)
dataset.shape
# Out:
# (903653, 45)

# %%
dataset.to_pickle('dataset.pkl')

# %% [markdown]
# Checkpoint 1 :Import Libraries and start from here.

# %%
dataset = pd.read_pickle('dataset.pkl')

# %%
dataset.head(5)
# Out:
#   channelGrouping      date        fullVisitorId  \
# 0  Organic Search  20160902  1131660440785968503
# 1  Organic Search  20160902   377306020877927890
# 2  Organic Search  20160902  3895546263509774583
# 3  Organic Search  20160902  4763447161404445595
# 4  Organic Search  20160902    27294437909732085
#
#                         sessionId  socialEngagementType     visitId  \
# 0  1131660440785968503_1472830385  Not Socially Engaged  1472830385
# 1   377306020877927890_1472880147  Not Socially Engaged  1472880147
# 2  3895546263509774583_1472865386  Not Socially Engaged  1472865386
# 3  4763447161404445595_1472881213  Not Socially Engaged  1472881213
# 4    27294437909732085_1472822600  Not Socially Engaged  1472822600
#
#    visitNumber  visitStartTime     browser                 browserVersion  \
# 0            1      1472830385      Chrome  not available in demo dataset
# 1            1      1472880147     Firefox  not available in demo dataset
# ...

# %%
#Dropping the last column adwordsClickInfo, since the dictionary contained in it does contain many values that are useful
dataset = dataset.drop('adwordsClickInfo', 1)
#checking for the number of unique values that is contained in each of the columns
for name in dataset.columns:
    print(name + ":"+ str(dataset[name].nunique()))
# Out:
# channelGrouping:8
# date:366
# fullVisitorId:742735
# sessionId:902755
# socialEngagementType:1
# visitId:886303
# visitNumber:384
# visitStartTime:887159
# browser:54
# browserVersion:1
# browserSize:1
# operatingSystem:20
# operatingSystemVersion:1
# isMobile:2
# mobileDeviceBranding:1
# mobileDeviceModel:1
# mobileInputSelector:1
# mobileDeviceInfo:1
# mobileDeviceMarketingName:1
# flashVersion:1
# language:1
# screenColors:1
# screenResolution:1
# deviceCategory:3
# visits:1
# hits:274
# pageviews:213
# bounces:1
# newVisits:1
# continent:6
# subContinent:23
# country:222
# region:376
# metro:94
# city:649
# cityId:1
# networkDomain:28064
# latitude:1
# longitude:1
# networkLocation:1
# campaign:10
# source:380
# medium:7
# keyword:3659

# %% [markdown]
# Checking the columns that showed only one unique values and dropping it if needed , since it would not contribute to prediction.

# %%
oneUnique=[]
for name in dataset.columns:
    if(dataset[name].nunique()==1):
        print(name + ":"+ str(dataset[name].nunique()))
        oneUnique.append(name)

print(oneUnique)
# Out:
# socialEngagementType:1
# browserVersion:1
# browserSize:1
# operatingSystemVersion:1
# mobileDeviceBranding:1
# mobileDeviceModel:1
# mobileInputSelector:1
# mobileDeviceInfo:1
# mobileDeviceMarketingName:1
# flashVersion:1
# language:1
# screenColors:1
# screenResolution:1
# visits:1
# bounces:1
# newVisits:1
# cityId:1
# latitude:1
# longitude:1
# networkLocation:1
# ['socialEngagementType', 'browserVersion', 'browserSize', 'operatingSystemVersion', 'mobileDeviceBranding', 'mobileDeviceModel', 'mobileInputSelector', 'mobileDeviceInfo', 'mobileDeviceMarketingName', 'flashVersion', 'language', 'screenColors', 'screenResolution', 'visits', 'bounces', 'newVisits', 'cityId', 'latitude', 'longitude', 'networkLocation']

# %%
#print all the unique value for the columns that are said to have only one unique values
for name in oneUnique:
    print(dataset[name].unique())
# Out:
# ['Not Socially Engaged']
# ['not available in demo dataset']
# ['not available in demo dataset']
# ['not available in demo dataset']
# ['not available in demo dataset']
# ['not available in demo dataset']
# ['not available in demo dataset']
# ['not available in demo dataset']
# ['not available in demo dataset']
# ['not available in demo dataset']
# ['not available in demo dataset']
# ['not available in demo dataset']
# ['not available in demo dataset']
# ['1']
# ['1' None]
# ['1' None]
# ['not available in demo dataset']
# ['not available in demo dataset']
# ['not available in demo dataset']
# ['not available in demo dataset']

# %%
#drop the above columns from the dataset
for name in oneUnique:
    dataset = dataset.drop(name, 1)

# %%
print(len(oneUnique))
print(dataset.shape)
# Out:
# 20
# (903653, 24)

# %%
dataset.head(5)
# Out:
#   channelGrouping      date        fullVisitorId  \
# 0  Organic Search  20160902  1131660440785968503
# 1  Organic Search  20160902   377306020877927890
# 2  Organic Search  20160902  3895546263509774583
# 3  Organic Search  20160902  4763447161404445595
# 4  Organic Search  20160902    27294437909732085
#
#                         sessionId     visitId  visitNumber  visitStartTime  \
# 0  1131660440785968503_1472830385  1472830385            1      1472830385
# 1   377306020877927890_1472880147  1472880147            1      1472880147
# 2  3895546263509774583_1472865386  1472865386            1      1472865386
# 3  4763447161404445595_1472881213  1472881213            1      1472881213
# 4    27294437909732085_1472822600  1472822600            2      1472822600
#
#       browser operatingSystem  isMobile       ...            subContinent  \
# 0      Chrome         Windows     False       ...            Western Asia
# ...

# %%
for name in dataset.columns:
    print(name + ":"+ str(dataset[name].nunique()))
# Out:
# channelGrouping:8
# date:366
# fullVisitorId:742735
# sessionId:902755
# visitId:886303
# visitNumber:384
# visitStartTime:887159
# browser:54
# operatingSystem:20
# isMobile:2
# deviceCategory:3
# hits:274
# pageviews:213
# continent:6
# subContinent:23
# country:222
# region:376
# metro:94
# city:649
# networkDomain:28064
# campaign:10
# source:380
# medium:7
# keyword:3659

# %%
dataset.channelGrouping.unique()
# Out:
# array(['Organic Search', 'Referral', 'Paid Search', 'Affiliates',
#        'Direct', 'Display', 'Social', '(Other)'], dtype=object)

# %%
print(max(dataset.date))
print(min(dataset.date))
# Out:
# 20170801
# 20160801

# %%
dataset.head(5)
# Out:
#   channelGrouping      date        fullVisitorId  \
# 0  Organic Search  20160902  1131660440785968503
# 1  Organic Search  20160902   377306020877927890
# 2  Organic Search  20160902  3895546263509774583
# 3  Organic Search  20160902  4763447161404445595
# 4  Organic Search  20160902    27294437909732085
#
#                         sessionId     visitId  visitNumber  visitStartTime  \
# 0  1131660440785968503_1472830385  1472830385            1      1472830385
# 1   377306020877927890_1472880147  1472880147            1      1472880147
# 2  3895546263509774583_1472865386  1472865386            1      1472865386
# 3  4763447161404445595_1472881213  1472881213            1      1472881213
# 4    27294437909732085_1472822600  1472822600            2      1472822600
#
#       browser operatingSystem  isMobile       ...            subContinent  \
# 0      Chrome         Windows     False       ...            Western Asia
# ...

# %%
dataset[dataset.fullVisitorId.duplicated()]
# Out:
#        channelGrouping      date        fullVisitorId  \
# 69      Organic Search  20160902  8720204952657722494
# 136     Organic Search  20160902  1428270067204482740
# 185             Direct  20160902  0949718915643445721
# 199           Referral  20160902  2628175916794749307
# 228           Referral  20160902  0440206142725306353
# 254           Referral  20160902  0440206142725306353
# 255           Referral  20160902  3523749053085989464
# 262           Referral  20160902  0440206142725306353
# 269     Organic Search  20160902  8770237469311081313
# 298     Organic Search  20160902  6196078553790218166
# 299     Organic Search  20160902   240989783927851488
# 364     Organic Search  20160902  0877259160433732747
# 368           Referral  20160902  7974486524940955098
# 372     Organic Search  20160902  0854783508496317255
# 410           Referral  20160902  1442383558497981936
# 449     Organic Search  20160902  5264054794625558679
# ...

# %%
dataset[dataset.fullVisitorId=='0949718915643445721']
# Out:
#        channelGrouping      date        fullVisitorId  \
# 147             Direct  20160902  0949718915643445721
# 185             Direct  20160902  0949718915643445721
# 11685           Direct  20160811  0949718915643445721
# 51987           Direct  20161014  0949718915643445721
# 59867           Direct  20160831  0949718915643445721
# 396087          Direct  20161002  0949718915643445721
# 396159          Direct  20161002  0949718915643445721
# 396172          Direct  20161002  0949718915643445721
# 397892          Direct  20160909  0949718915643445721
# 397899          Direct  20160909  0949718915643445721
# 397904          Direct  20160909  0949718915643445721
# 397910          Direct  20160909  0949718915643445721
# 397912          Direct  20160909  0949718915643445721
# 398015          Direct  20160909  0949718915643445721
# 408408          Direct  20160904  0949718915643445721
# 423987          Direct  20160914  0949718915643445721
# ...

# %%
pd.to_datetime(dataset.visitStartTime)
# Out:
# 0        1970-01-01 00:00:01.472830385
# 1        1970-01-01 00:00:01.472880147
# 2        1970-01-01 00:00:01.472865386
# 3        1970-01-01 00:00:01.472881213
# 4        1970-01-01 00:00:01.472822600
# 5        1970-01-01 00:00:01.472807194
# 6        1970-01-01 00:00:01.472817241
# 7        1970-01-01 00:00:01.472812602
# 8        1970-01-01 00:00:01.472805784
# 9        1970-01-01 00:00:01.472812272
# 10       1970-01-01 00:00:01.472834967
# 11       1970-01-01 00:00:01.472849434
# 12       1970-01-01 00:00:01.472839882
# 13       1970-01-01 00:00:01.472803483
# 14       1970-01-01 00:00:01.472868337
# 15       1970-01-01 00:00:01.472824614
# 16       1970-01-01 00:00:01.472801099
# 17       1970-01-01 00:00:01.472826820
# 18       1970-01-01 00:00:01.472804607
# 19       1970-01-01 00:00:01.472856874
# 20       1970-01-01 00:00:01.472826420
# 21       1970-01-01 00:00:01.472863754
# 22       1970-01-01 00:00:01.472872530
# 23       1970-01-01 00:00:01.472808484
# ...
