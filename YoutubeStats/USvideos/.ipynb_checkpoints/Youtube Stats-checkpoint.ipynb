# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
#import matplotlib.pylab as plt

# %%
dataset = pd.read_csv('USvideos.csv')

# %%
dataset.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40949.000000  4.094900e+04  4.094900e+04  4.094900e+04   4.094900e+04
# mean      19.972429  2.360785e+06  7.426670e+04  3.711401e+03   8.446804e+03
# std        7.568327  7.394114e+06  2.288853e+05  2.902971e+04   3.743049e+04
# min        1.000000  5.490000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       17.000000  2.423290e+05  5.424000e+03  2.020000e+02   6.140000e+02
# 50%       24.000000  6.818610e+05  1.809100e+04  6.310000e+02   1.856000e+03
# 75%       25.000000  1.823157e+06  5.541700e+04  1.938000e+03   5.755000e+03
# max       43.000000  2.252119e+08  5.613827e+06  1.674420e+06   1.361580e+06

# %%
dataset.head(5)
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
dataset.columns
dataset['title'].value_counts()

dataset.trending_date = pd.to_datetime(dataset.trending_date)
dataset['trending_date'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     376             try:
# --> 377                 values, tz = conversion.datetime_to_datetime64(arg)
#     378                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-7261a8f04e13> in <module>()
#       2 dataset['title'].value_counts()
#       3
# ----> 4 dataset.trending_date = pd.to_datetime(dataset.trending_date)
#       5 dataset['trending_date'].value_counts()
#
# ...

# %%
dataset.shape
# Out:
# (40949, 16)

# %%
dataset[dataset['title']=='We Bought A House']
# Out:
#           video_id trending_date              title channel_title  \
# 35354  -kTWIm7m4Uw      18.18.05  We Bought A House  JennaMarbles
# 35560  -kTWIm7m4Uw      18.19.05  We Bought A House  JennaMarbles
# 35765  -kTWIm7m4Uw      18.20.05  We Bought A House  JennaMarbles
# 36002  -kTWIm7m4Uw      18.21.05  We Bought A House  JennaMarbles
# 36215  -kTWIm7m4Uw      18.22.05  We Bought A House  JennaMarbles
# 36424  -kTWIm7m4Uw      18.23.05  We Bought A House  JennaMarbles
# 36634  -kTWIm7m4Uw      18.24.05  We Bought A House  JennaMarbles
# 36841  -kTWIm7m4Uw      18.25.05  We Bought A House  JennaMarbles
# 37054  -kTWIm7m4Uw      18.26.05  We Bought A House  JennaMarbles
# 37267  -kTWIm7m4Uw      18.27.05  We Bought A House  JennaMarbles
# 37471  -kTWIm7m4Uw      18.28.05  We Bought A House  JennaMarbles
# 37672  -kTWIm7m4Uw      18.29.05  We Bought A House  JennaMarbles
# 37878  -kTWIm7m4Uw      18.30.05  We Bought A House  JennaMarbles
# ...

# %%
X = dataset.iloc[:, [1,3,5,6,12]].values

# %%
dataset.date = pd.to_datetime(dataset.date)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-4ddbdbfb4fef> in <module>()
# ----> 1 dataset.date = pd.to_datetime(dataset.date)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'date'

# %%
dataset['video_id'].value_counts()
# Out:
# j4KvrAUjn6c    30
# 8h--kFui1JA    29
# iILJvqrAQ_w    29
# MAjY8mCTXWk    29
# NBSAQenU2Bk    29
# r-3iathMo7o    29
# QBL8IRJ5yHU    29
# t4pRQ0jn23Q    29
# ulNswX3If6U    28
# mdWcaWBxxcY    28
# 6S9c5nnDd_s    28
# UfKmSfgFxi8    28
# YI3tsmFsrOg    28
# vjSohj-Iclc    28
# WIV3xNz8NoM    28
# 2PH7dK6SLC8    28
# TjXQzRWmb_I    27
# nRc0kmOYgzQ    27
# 0zZ0Y_UZRBw    27
# um-1fAVU1OQ    27
# H7gh2fmdjCU    27
# 1purAy2MsOc    27
# pFc6I0rgmgY    27
# -kTWIm7m4Uw    27
# Xpv-sEKl1B4    27
# 6SuMbFuKDf8    27
# BspHjvU11y4    27
# D6Oy4LfoqsU    26
# ooyjaVdt-jA    26
# ju_inUnrLc4    26
#                ..
# pDf5sHgvo0A     1
# _C14eXiZQWo     1
# _LnZrXrdC00     1
# yc2m1LLa9l4     1
# CFwXUarN-wg     1
# r8vFZ0HAaz0     1
# ui05f6CoIxA     1
# Zvg6b6q1s-Y     1
# TSqwDQHE1J8     1
# 4IsdxwBMX1g     1
# F0rXPrnC_Ps     1
# 89PKbJ2NAqc     1
# djlaHJCXT4o     1
# jtVz0qxQM_U     1
# 77e7n60Zs9E     1
# 2fZ-qIHlA5M     1
# thIRJLsnIxY     1
# v_5qKt7M5fM     1
# rf3iHqE240I     1
# ...

# %%
dataset['video_id'].nunique()
# Out:
# 6351

# %%
grouped = dataset.groupby(by = 'video_id')

# %%
likes = pd.DataFrame(grouped["likes"].sum()).reset_index()

# %%
likes.nunique()
# dataset[dataset.video_id=='-0CMnp02rNY']
# Out:
# video_id    6351
# likes       6021
# dtype: int64

# %%
dataset['comments_disabled'].value_counts()
k =pd.DataFrame(dataset['comments_disabled'].value_counts())

# %%
dataset['comments_disabled'].value_counts().plot(kind='bar')
dataset['comments_disabled'].value_counts().plot(kind='bar')

# %%
fig = plt.figure() 
ax = fig.add_subplot(111)
ax.bar(x=list(k.index),height=list(k.comments_disabled))
ax.set(title=k.columns[0])
# ax.plot(k.value_counts, color='lightblue', linewidth=3)
# Out:
# [Text(0.5,1,'comments_disabled')]

# %%
dataset.isnull().any(axis=0)
# Out:
# video_id                  False
# trending_date             False
# title                     False
# channel_title             False
# category_id               False
# publish_time              False
# tags                      False
# views                     False
# likes                     False
# dislikes                  False
# comment_count             False
# thumbnail_link            False
# comments_disabled         False
# ratings_disabled          False
# video_error_or_removed    False
# description                True
# dtype: bool

# %%
dataset['description'].isnull().sum()
# Out:
# 570

# %%
dataset.loc[dataset.isnull().any(axis=1)]
# Out:
#           video_id trending_date  \
# 42     NZFhMSgbKKM      17.14.11
# 47     sbcbvuitiTc      17.14.11
# 175    4d07RXYLsJE      17.14.11
# 267    NZFhMSgbKKM      17.15.11
# 312    sbcbvuitiTc      17.15.11
# 446    upEIZAihcwo      17.16.11
# 523    NZFhMSgbKKM      17.16.11
# 632    U5sCjnezw4o      17.17.11
# 678    upEIZAihcwo      17.17.11
# 750    NZFhMSgbKKM      17.17.11
# 846    U5sCjnezw4o      17.18.11
# 910    upEIZAihcwo      17.18.11
# 988    NZFhMSgbKKM      17.18.11
# 1040   U5sCjnezw4o      17.19.11
# 1129   aHsfKnrNCG4      17.19.11
# 1131   CvpwGru3s7s      17.19.11
# 1133   upEIZAihcwo      17.19.11
# 1137   aujUl3yt6nM      17.19.11
# 1253   U5sCjnezw4o      17.20.11
# 1345   aHsfKnrNCG4      17.20.11
# 1356   aujUl3yt6nM      17.20.11
# 1360   CvpwGru3s7s      17.20.11
# 1362   upEIZAihcwo      17.20.11
# 1413   aVpvVq_yZLM      17.21.11
# 1517   U5sCjnezw4o      17.21.11
# 1589   aHsfKnrNCG4      17.21.11
# 1599   aujUl3yt6nM      17.21.11
# ...

# %%
df=dataset.dropna(axis=0)
df.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40379.000000  4.037900e+04  4.037900e+04  4.037900e+04   4.037900e+04
# mean      19.944253  2.370839e+06  7.461677e+04  3.508122e+03   8.287396e+03
# std        7.594850  7.428515e+06  2.296172e+05  2.317486e+04   3.431605e+04
# min        1.000000  5.490000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       17.000000  2.470760e+05  5.621500e+03  2.050000e+02   6.230000e+02
# 50%       24.000000  6.895970e+05  1.837100e+04  6.370000e+02   1.874000e+03
# 75%       25.000000  1.834912e+06  5.567200e+04  1.948000e+03   5.787000e+03
# max       43.000000  2.252119e+08  5.613827e+06  1.643059e+06   1.228655e+06

# %%
df[df['video_id']=='QBL8IRJ5yHU']
# Out:
#           video_id trending_date  \
# 34750  QBL8IRJ5yHU      18.15.05
# 34899  QBL8IRJ5yHU      18.15.05
# 34952  QBL8IRJ5yHU      18.16.05
# 35168  QBL8IRJ5yHU      18.17.05
# 35385  QBL8IRJ5yHU      18.18.05
# 35589  QBL8IRJ5yHU      18.19.05
# 35792  QBL8IRJ5yHU      18.20.05
# 36028  QBL8IRJ5yHU      18.21.05
# 36237  QBL8IRJ5yHU      18.22.05
# 36445  QBL8IRJ5yHU      18.23.05
# 36654  QBL8IRJ5yHU      18.24.05
# 36861  QBL8IRJ5yHU      18.25.05
# 37073  QBL8IRJ5yHU      18.26.05
# 37285  QBL8IRJ5yHU      18.27.05
# 37487  QBL8IRJ5yHU      18.28.05
# 37688  QBL8IRJ5yHU      18.29.05
# 37893  QBL8IRJ5yHU      18.30.05
# 38101  QBL8IRJ5yHU      18.31.05
# 38301  QBL8IRJ5yHU      18.01.06
# 38504  QBL8IRJ5yHU      18.02.06
# 38708  QBL8IRJ5yHU      18.03.06
# 38911  QBL8IRJ5yHU      18.04.06
# 39115  QBL8IRJ5yHU      18.05.06
# 39320  QBL8IRJ5yHU      18.06.06
# 39523  QBL8IRJ5yHU      18.07.06
# 39725  QBL8IRJ5yHU      18.08.06
# 39932  QBL8IRJ5yHU      18.09.06
# ...

# %%
df=df.drop_duplicates()

# %%
df.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40332.000000  4.033200e+04  4.033200e+04  4.033200e+04   4.033200e+04
# mean      19.942552  2.370824e+06  7.462234e+04  3.508185e+03   8.289092e+03
# std        7.595933  7.432121e+06  2.297311e+05  2.318773e+04   3.433488e+04
# min        1.000000  5.490000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       17.000000  2.466670e+05  5.615500e+03  2.040000e+02   6.230000e+02
# 50%       24.000000  6.884230e+05  1.835150e+04  6.360000e+02   1.873000e+03
# 75%       25.000000  1.832174e+06  5.563025e+04  1.945250e+03   5.785000e+03
# max       43.000000  2.252119e+08  5.613827e+06  1.643059e+06   1.228655e+06

# %%
k = pd.DataFrame(df.groupby('video_id')['likes'].mean())

# %%
df.head(50)
df.channel_title.value_counts().head(20)
likes_On_channel_title=pd.DataFrame(df.groupby('channel_title')['likes'].mean())

# %%
k.__class__.__name__
k.head()
# Out:
#                     likes
# video_id
# -0CMnp02rNY   8699.500000
# -0NYY8cqdiQ   4429.000000
# -1Hm41N0dUs  37388.333333
# -1yT-K3c6YI   6826.250000
# -2RVw2_QyxQ    450.333333

# %%
likes_On_channel_title
likes_On_channel_title.sort_values(by='likes').tail(10).plot(kind='bar',title="Average likes for Channel")

# %%
pd.DataFrame(df.groupby('channel_title')['dislikes'].mean()).sort_values(by='dislikes').tail(10).plot(kind='bar',title="Average dislikes for Channel")

# %%
pd.DataFrame(df.groupby('channel_title')['comment_count'].mean()).sort_values(by='comment_count').tail(10).plot(kind='bar',title="Average comment_count for Channel")

# %%
listOfAttributesToPlot = ['comment_count','dislikes','likes']
by='channel_title'
for attr in listOfAttributesToPlot:
    pd.DataFrame(df.groupby(by)[attr].mean()).sort_values(by=attr).tail(10).plot(kind='bar',title="Average "+attr+" for "+by)

# %%
df.publish_time=pd.to_datetime(df.publish_time)

# %%
listOfAttributesToPlot = ['comment_count','dislikes','likes']
by='category_id'
for attr in listOfAttributesToPlot:
    pd.DataFrame(df.groupby(by)[attr].mean()).sort_values(by=attr).tail(10).plot(kind='bar',title="Average "+attr+" for "+by)

# %%
df
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# 5      gHZ1Qz0KiKM      17.14.11
# 6      39idVpFF7NQ      17.14.11
# 7      nc99ccSXST0      17.14.11
# 8      jr9QtXwC9vc      17.14.11
# 9      TUmyygCMMGA      17.14.11
# 10     9wRQljFNDW8      17.14.11
# 11     VifQlJit6A0      17.14.11
# 12     5E4ZBSInqUU      17.14.11
# 13     GgVmn66oK_A      17.14.11
# 14     TaTleo4cOs8      17.14.11
# 15     kgaO45SyaO4      17.14.11
# 16     ZAQs-ctOqXQ      17.14.11
# 17     YVfyYrEmzgM      17.14.11
# 18     eNSN6qet1kE      17.14.11
# 19     B5HORANmzHw      17.14.11
# 20     vU14JY3x81A      17.14.11
# 21     6VhU_T463sU      17.14.11
# 22     _-aDHxoblr4      17.14.11
# 23     JBZTZZAcFTw      17.14.11
# 24     lZ68j2J_GOM      17.14.11
# 25     dRpNZV18N_g      17.14.11
# 26     fcVjitaM3LY      17.14.11
# ...

# %%
print(max(df.publish_time))
print(min(df.publish_time))
# Out:
# 2018-06-14 01:31:53
# 2006-07-23 08:24:11

# %%
df.set_index('publish_time', inplace=True)
# df.reset_index()

# %%
df['publish_year']=df.index.year
df['publish_month']=df.index.month
df['publish_day']=df.index.day
df['publish_dayofweek']=df.index.dayofweek

# %%
df
# Out:
#                         video_id trending_date  \
# publish_time
# 2017-11-13 17:13:01  2kyS6SvSYSE      17.14.11
# 2017-11-13 07:30:00  1ZAPwfrtAFY      17.14.11
# 2017-11-12 19:05:24  5qpjK5DgCt4      17.14.11
# 2017-11-13 11:00:04  puqaWrEC7tY      17.14.11
# 2017-11-12 18:01:41  d380meD0W0M      17.14.11
# 2017-11-13 19:07:23  gHZ1Qz0KiKM      17.14.11
# 2017-11-12 05:37:17  39idVpFF7NQ      17.14.11
# 2017-11-12 21:50:37  nc99ccSXST0      17.14.11
# 2017-11-13 14:00:23  jr9QtXwC9vc      17.14.11
# 2017-11-13 13:45:16  TUmyygCMMGA      17.14.11
# 2017-11-13 02:05:26  9wRQljFNDW8      17.14.11
# 2017-11-13 03:00:00  VifQlJit6A0      17.14.11
# 2017-11-13 17:00:00  5E4ZBSInqUU      17.14.11
# 2017-11-12 14:00:00  GgVmn66oK_A      17.14.11
# 2017-11-12 18:30:01  TaTleo4cOs8      17.14.11
# 2017-11-13 20:09:58  kgaO45SyaO4      17.14.11
# 2017-11-12 17:00:05  ZAQs-ctOqXQ      17.14.11
# 2017-11-13 16:00:07  YVfyYrEmzgM      17.14.11
# 2017-11-13 15:30:17  eNSN6qet1kE      17.14.11
# ...

# %%
listOfAttributesToPlot = ['comment_count','dislikes','likes']
by='publish_year'
for attr in listOfAttributesToPlot:
    pd.DataFrame(df.groupby(by)[attr].mean()).sort_values(by=attr).tail(10).plot(kind='bar',title="Average "+attr+" for "+by)

# %%
listOfAttributesToPlot = ['comment_count','dislikes','likes']
by='publish_month'
for attr in listOfAttributesToPlot:
    pd.DataFrame(df.groupby(by)[attr].mean()).sort_values(by=attr).tail(10).plot(kind='bar',title="Average "+attr+" for "+by)

# %%
listOfAttributesToPlot = ['comment_count','dislikes','likes']
by='publish_day'
for attr in listOfAttributesToPlot:
    pd.DataFrame(df.groupby(by)[attr].mean()).sort_values(by=attr).tail(10).plot(kind='bar',title="Average "+attr+" for "+by)

# %%
listOfAttributesToPlot = ['comment_count','dislikes','likes']
by='publish_dayofweek'
for attr in listOfAttributesToPlot:
    pd.DataFrame(df.groupby(by)[attr].mean()).sort_values(by=attr).tail(10).plot(kind='bar',title="Average "+attr+" for "+by)
